# %% [markdown]
# ## PART - I
# ### Description
# #### MtCars , an automobile company in Chambersburg, United States has recorded the production of its cars in a dataset. Thecompany is coming up with a new model based on the feedback given by its customers. It has to explore the current dataset to derive further insights from it .

# %% [markdown]
# #### Data Description:
# #### variable description
# #### mpg Miles/(US) gallon
# #### cyl Number of cylinders
# #### disp Displacement (cu.in.)
# #### hp Gross horsepower
# #### drat Rear axle ratio
# #### wt Weight (lb/1000)
# #### qsec 1/4 mile time
# #### vs V/S
# #### am Transmission (0 = automatic, 1 = manual)
# #### gear Number of forward gears
# #### carb Number of carburetors

# %% [markdown]
# #### Objective :
# #### Import the dataset , explore the dimensionality , and type and average value of the horsepower across all the cars . Also ,
# #### identify a few of mostly correlated features , which would help n modification

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dfcars=pd.read_csv("mtcars.csv",sep=',')
dfcars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#Top 5 Rows of MTCars Dataset
dfcars.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
#Bottom 5 Rows of MTCars Dataset
dfcars.tail()
# Out:
#              model   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %%
#Getting Dimensions of MTCars Dataset
dfcars.ndim
# Out:
# 2

# %%
#Getting Rows and Columns of MTCars Dataset
dfcars.shape
# Out:
# (32, 12)

# %%
#DataTypes of MTCars Dataset
dfcars.dtypes
# Out:
# model     object
# mpg      float64
# cyl        int64
# disp     float64
# hp         int64
# drat     float64
# wt       float64
# qsec     float64
# vs         int64
# am         int64
# gear       int64
# carb       int64
# dtype: object

# %%
#Statistical Summary of MTCars Dataset
dfcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
#Getting Mean of MT Cars
dfcars.mean()
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
#Finding out Null values in MTCars Dataset
dfcars.isnull().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
#Getting the Median in MTCars Dataset
dfcars.median()
# Out:
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
#Getting the aggregate statistics
dfcars.aggregate({'cyl': ['min', 'max', 'median', 'skew'],'wt': ['min', 'max', 'median', 'mean']})
# Out:
#              cyl       wt
# max     8.000000  5.42400
# mean         NaN  3.21725
# median  6.000000  3.32500
# min     4.000000  1.51300
# skew   -0.192261      NaN

# %%
# Calculate Average value of the horsepower across all the cars
dfcars[["model", "hp"]].groupby("model").mean()
# Out:
#                       hp
# model
# AMC Javelin          150
# Cadillac Fleetwood   205
# Camaro Z28           245
# Chrysler Imperial    230
# Datsun 710            93
# Dodge Challenger     150
# Duster 360           245
# Ferrari Dino         175
# Fiat 128              66
# Fiat X1-9             66
# Ford Pantera L       264
# Honda Civic           52
# Hornet 4 Drive       110
# Hornet Sportabout    175
# Lincoln Continental  215
# Lotus Europa         113
# Maserati Bora        335
# Mazda RX4            110
# Mazda RX4 Wag        110
# Merc 230              95
# Merc 240D             62
# Merc 280             123
# Merc 280C            123
# Merc 450SE           180
# Merc 450SL           180
# Merc 450SLC          180
# Pontiac Firebird     175
# Porsche 914-2         91
# Toyota Corolla        65
# Toyota Corona         97
# Valiant              105
# Volvo 142E           109

# %%
#identify a few of mostly correlated features , which would help n modification
dfcars.corr()
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(dfcars.corr(),cmap="PRGn",annot=True)

# %% [markdown]
# ## PART - II
# ### Description
# #### Mtcars, the automobile company in the United States , has planned to rework on optimizing the horsepower of its cars as most of the customers' feedback was centered around the horsepower. However , while developing an ML model with respect to horsepower, The efficiency of the model was compromised . Irregularity might be one of the causes
#
# #### Objective :
# #### Check for the missing values and outliers within the horsepower column and remove them.

# %%
#Checking for missing values
dfcars[dfcars['hp'].isnull()]
# Out:
# Empty DataFrame
# Columns: [model, mpg, cyl, disp, hp, drat, wt, qsec, vs, am, gear, carb]
# Index: []

# %%
sns.boxplot(dfcars['hp'])

# %%
#Interquartile Range
Q1Cars=dfcars.quantile(0.25)
Q2Cars=dfcars.quantile(0.5)
Q3Cars=dfcars.quantile(0.75)
IQRCars=Q3Cars-Q1Cars

# %%
print("--------------------Q1 ---------------------------\n",Q1Cars,"\n","----------------------Q2------------------------\n",Q2Cars,"\n","--------------------------Q3------------------------\n",Q3Cars,"\n","------------------------------IQR-----------------------------\n",IQRCars)
# Out:
# --------------------Q1 ---------------------------
#  mpg      15.42500
# cyl       4.00000
# disp    120.82500
# hp       96.50000
# drat      3.08000
# wt        2.58125
# qsec     16.89250
# vs        0.00000
# am        0.00000
# gear      3.00000
# carb      2.00000
# Name: 0.25, dtype: float64
#  ----------------------Q2------------------------
#  mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# Name: 0.5, dtype: float64
#  --------------------------Q3------------------------
#  mpg      22.80
# cyl       8.00
# disp    326.00
# hp      180.00
# drat      3.92
# wt        3.61
# qsec     18.90
# vs        1.00
# am        1.00
# gear      4.00
# carb      4.00
# Name: 0.75, dtype: float64
#  ------------------------------IQR-----------------------------
#  mpg       7.37500
# cyl       4.00000
# disp    205.17500
# ...

# %%
Q1Hp=dfcars['hp'].quantile(0.25)
Q2Hp=dfcars['hp'].quantile(0.5)
Q3Hp=dfcars['hp'].quantile(0.75)
IQRHp=Q3Hp-Q1Hp
# Range -- Q1-1.5*IQR<value<Q3+1.5*IQR
floorHp=Q1Hp-1.5*IQRHp
capHp=Q3Hp+1.5*IQRHp
print("Q1\n",Q1Hp,"\nQ2\n",Q2Hp,"\nQ3\n",Q3Hp,"\nQ4\n",IQRHp)
print("Floor\n",floorHp,"\nCap\n",capHp)
Q5Hp=dfcars['hp'].quantile(0.05)
Q95Hp=dfcars['hp'].quantile(0.95)
print("Q5HP\n",Q5Hp,"\nQ95HP\n",Q95Hp)
# Out:
# Q1
#  96.5
# Q2
#  123.0
# Q3
#  180.0
# Q4
#  83.5
# Floor
#  -28.75
# Cap
#  305.25
# Q5HP
#  63.65
# Q95HP
#  253.54999999999998

# %%
dfcars['hp'].describe()
# Out:
# count     32.000000
# mean     146.687500
# std       68.562868
# min       52.000000
# 25%       96.500000
# 50%      123.000000
# 75%      180.000000
# max      335.000000
# Name: hp, dtype: float64

# %%
#As 95th Percentile is around 250 so removing outliers after 250
hp_outlier = dfcars[(dfcars['hp'] >= 250)].index
dfcars.drop(hp_outlier, inplace=True)

# %%
dfcars['hp'].describe()
# Out:
# count     30.00000
# mean     136.50000
# std       56.74793
# min       52.00000
# 25%       95.50000
# 50%      118.00000
# 75%      178.75000
# max      245.00000
# Name: hp, dtype: float64

# %%
sns.boxplot(x=dfcars['hp'])
